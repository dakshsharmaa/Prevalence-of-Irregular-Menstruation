# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv("https://raw.githubusercontent.com/dakshsharmaa/Prevalence-of-Irregular-Menstruation/Data/PIM_(320).csv")

# %%
data.head()
# Out:
#    Unnamed: 0  Age   BMI  Height (in cm)  Weight (in kg)  Age at Menarche  \
# 0           0   20  21.2           155.0            51.0             15.0
# 1           1   20  22.8           154.0            54.0             14.0
# 2           2   18  21.1           160.0            54.0             11.0
# 3           3   19  18.2           160.0            46.7             13.0
# 4           4   18  21.6           162.5            57.0             13.0
#
#    Length of menstrual cycle  Length of periods  Menstrual flow  \
# 0                         25                  4               1
# 1                         30                  4               1
# 2                         28                  5               2
# 3                         33                  3               1
# 4                         25                  5               1
#
#    Irregular menstruation (Y/N)  ...  Consumption of vitamin C  \
# 0                             1  ...                         3
# ...

# %%
data = data.iloc[: , 1:]

# %%
pd.set_option("display.max_columns",None)
data.head()
# Out:
#    Age   BMI  Height (in cm)  Weight (in kg)  Age at Menarche  \
# 0   20  21.2           155.0            51.0             15.0
# 1   20  22.8           154.0            54.0             14.0
# 2   18  21.1           160.0            54.0             11.0
# 3   19  18.2           160.0            46.7             13.0
# 4   18  21.6           162.5            57.0             13.0
#
#    Length of menstrual cycle  Length of periods  Menstrual flow  \
# 0                         25                  4               1
# 1                         30                  4               1
# 2                         28                  5               2
# 3                         33                  3               1
# 4                         25                  5               1
#
#    Irregular menstruation (Y/N)  Irregular menstruation (Months)  \
# 0                             1                              0.0
# 1                             0                              NaN
# ...

# %%
data.iloc[: , 0:10].describe()
# Out:
#               Age         BMI  Height (in cm)  Weight (in kg)  \
# count  320.000000  320.000000      320.000000      320.000000
# mean    19.731250   22.026875      161.949415       53.814219
# std      2.749116    3.994851       15.099503       16.328552
# min     15.000000    3.200000      146.000000       10.000000
# 25%     18.000000   19.575000      155.000000       48.000000
# 50%     19.000000   21.900000      160.020000       55.000000
# 75%     20.000000   24.025000      165.625000       64.000000
# max     42.000000   39.000000      401.000000      110.000000
#
#        Age at Menarche  Length of menstrual cycle  Length of periods  \
# count       320.000000                 320.000000         320.000000
# mean         12.800000                  29.675000           4.906250
# std           1.474124                   8.540921           1.486815
# min           8.000000                   0.000000           1.000000
# ...

# %%
data.iloc[: , 10:27].describe()
# Out:
#        Irregular cycle (Y/N)  Medications (Y/N)  \
# count             205.000000         205.000000
# mean                0.434146           0.331707
# std                 0.496858           0.471979
# min                 0.000000           0.000000
# 25%                 0.000000           0.000000
# 50%                 0.000000           0.000000
# 75%                 1.000000           1.000000
# max                 1.000000           1.000000
#
#        Birth control meds/Surgery (Y/N)  Consumption of balanced diet  \
# count                        205.000000                    320.000000
# mean                           0.121951                      2.537500
# std                            0.328031                      0.848288
# min                            0.000000                      0.000000
# 25%                            0.000000                      2.000000
# 50%                            0.000000                      3.000000
# ...

# %%
cor = data.corr()

# %%
cor.iloc[: , 0:10]
# Out:
#                                        Age       BMI  Height (in cm)  \
# Age                               1.000000  0.260039       -0.051143
# BMI                               0.260039  1.000000       -0.275381
# Height (in cm)                   -0.051143 -0.275381        1.000000
# Weight (in kg)                    0.111296  0.551918        0.068797
# Age at Menarche                   0.078746 -0.066210        0.037878
# Length of menstrual cycle         0.004813 -0.031009        0.027486
# Length of periods                -0.114321 -0.101541       -0.008245
# Menstrual flow                   -0.017252  0.025908       -0.028299
# Irregular menstruation (Y/N)      0.076152  0.088813        0.067966
# Irregular menstruation (Months)   0.060940  0.091716       -0.028505
# Irregular cycle (Y/N)            -0.031674 -0.016581       -0.089987
# Medications (Y/N)                -0.008769  0.053898       -0.054598
# Birth control meds/Surgery (Y/N)  0.265059  0.207563       -0.053700
# ...

# %%
cor.iloc[: , 10:27]
# Out:
#                                   Irregular cycle (Y/N)  Medications (Y/N)  \
# Age                                           -0.031674          -0.008769
# BMI                                           -0.016581           0.053898
# Height (in cm)                                -0.089987          -0.054598
# Weight (in kg)                                -0.030651          -0.003916
# Age at Menarche                                0.008296           0.013670
# Length of menstrual cycle                      0.174992           0.157124
# Length of periods                              0.160490           0.212752
# Menstrual flow                                 0.128336           0.001086
# Irregular menstruation (Y/N)                        NaN                NaN
# Irregular menstruation (Months)                0.339565           0.272117
# Irregular cycle (Y/N)                          1.000000           0.219026
# ...

# %%
plt.subplots(figsize=(10,10))
sns.heatmap(cor,cmap="Pastel1", square=True);
