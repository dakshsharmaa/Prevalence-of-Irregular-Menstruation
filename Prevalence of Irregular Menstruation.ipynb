# %%
import pandas as pd
import numpy as np

# %%
pim_data=pd.read_csv('C:/Users/PREDATOR/Downloads/Prevalence of Irregular Menstruation.csv')

# %%
pim_data.head()
# Out:
#                          Timestamp  \
# 0  2021/07/15 11:31:31 AM GMT+5:30
# 1  2021/07/15 11:31:36 AM GMT+5:30
# 2  2021/07/15 11:32:48 AM GMT+5:30
# 3  2021/07/15 11:32:54 AM GMT+5:30
# 4  2021/07/15 11:34:00 AM GMT+5:30
#
#   By selecting 'I agree', you confirm that no coercion was exerted to fill this survey and you consent to provide information voluntarily without any monetary benefits attached to it. Do you agree?  \
# 0                                            I agree
# 1                                            I agree
# 2                                            I agree
# 3                                            I agree
# 4                                            I agree
#
#     Gender  Age  Height (in cm)  Weight (in kg)  Age at Menarche  \
# 0   Female   20           155.0            51.0               15
# 1   Female   20           154.0            54.0               14
# 2   Female   18           160.0            54.0               11
# ...

# %%
pim_data.tail()
# Out:
#                            Timestamp  \
# 284   2021/08/02 5:32:06 PM GMT+5:30
# 285   2021/08/04 9:08:42 PM GMT+5:30
# 286  2021/08/06 12:41:26 AM GMT+5:30
# 287   2021/08/06 8:35:16 AM GMT+5:30
# 288   2021/08/10 2:55:28 PM GMT+5:30
#
#     By selecting 'I agree', you confirm that no coercion was exerted to fill this survey and you consent to provide information voluntarily without any monetary benefits attached to it. Do you agree?  \
# 284                                            I agree
# 285                                            I agree
# 286                                            I agree
# 287                                            I agree
# 288                                            I agree
#
#       Gender  Age  Height (in cm)  Weight (in kg)  Age at Menarche  \
# 284   Female   16          158.00           45.00               12
# 285   Female   19          156.00           60.00               14
# ...

# %%
pim_data.isnull().sum()
# Out:
# Timestamp                                                                                                                                                                                                0
# By selecting 'I agree', you confirm that no coercion was exerted to fill this survey and you consent to provide information voluntarily without any monetary benefits attached to it. Do you agree?      0
# Gender                                                                                                                                                                                                   0
# Age                                                                                                                                                                                                      0
# ...

# %%
pim_data.shape
# Out:
# (289, 38)

# %%
pim_data.drop('Timestamp', axis='columns', inplace=True)

# %%
pim_data.head()
# Out:
#   By selecting 'I agree', you confirm that no coercion was exerted to fill this survey and you consent to provide information voluntarily without any monetary benefits attached to it. Do you agree?  \
# 0                                            I agree
# 1                                            I agree
# 2                                            I agree
# 3                                            I agree
# 4                                            I agree
#
#     Gender  Age  Height (in cm)  Weight (in kg)  Age at Menarche  \
# 0   Female   20           155.0            51.0               15
# 1   Female   20           154.0            54.0               14
# 2   Female   18           160.0            54.0               11
# 3  Female    19           160.0            46.7               13
# 4   Female   18           162.5            57.0               13
#
#    What is the length of your menstrual cycle?  \
# 0                                           25
# ...

# %%
gen = pim_data.pivot_table(index = ['Gender'], aggfunc ='size')
print(gen)
# Out:
# Gender
# Cis het female      1
# F                   8
# FEMALE              2
# Female            218
# Female             41
# Non-binary          1
# Woman               1
# female             13
# female              4
# dtype: int64

# %%
pim_data["Gender"].replace({"F": "Female", "FEMALE": "Female", "Woman": "Female", "female": "Female", "female ": "Female", "Female ": "Female"}, inplace=True)

# %%
gen = pim_data.pivot_table(index = ['Gender'], aggfunc ='size')
print(gen)
# Out:
# Gender
# Cis het female      1
# Female            287
# Non-binary          1
# dtype: int64

# %%
pim_data
# Out:
#     By selecting 'I agree', you confirm that no coercion was exerted to fill this survey and you consent to provide information voluntarily without any monetary benefits attached to it. Do you agree?  \
# 0                                              I agree
# 1                                              I agree
# 2                                              I agree
# 3                                              I agree
# 4                                              I agree
# ..                                                 ...
# 284                                            I agree
# 285                                            I agree
# 286                                            I agree
# 287                                            I agree
# 288                                            I agree
#
#      Gender  Age  Height (in cm)  Weight (in kg)  Age at Menarche  \
# 0    Female   20          155.00           51.00               15
# ...

# %%
# Cleaning values in column - Height (in cm)

# %%
pim_data.loc[pim_data["Height (in cm)"] < 10, "Height (in cm)"] = pim_data["Height (in cm)"] * 30.48
pim_data
# Out:
#     By selecting 'I agree', you confirm that no coercion was exerted to fill this survey and you consent to provide information voluntarily without any monetary benefits attached to it. Do you agree?  \
# 0                                              I agree
# 1                                              I agree
# 2                                              I agree
# 3                                              I agree
# 4                                              I agree
# ..                                                 ...
# 284                                            I agree
# 285                                            I agree
# 286                                            I agree
# 287                                            I agree
# 288                                            I agree
#
#      Gender  Age  Height (in cm)  Weight (in kg)        BMI  Age at Menarche  \
# 0    Female   20          155.00           51.00  21.227888               15
# ...

# %%
print(pim_data.iloc[28]['Height (in cm)'])
# Out:
# 161.54399999999998

# %%
pim_data.loc[pim_data["Height (in cm)"] < 90, "Height (in cm)"] = 0

# %%
print(pim_data.iloc[19]['Height (in cm)'])
# Out:
# 0.0

# %%
pim_data["Height (in cm)"].mean()
# Out:
# 161.11962629757787

# %%
pim_data.loc[pim_data["Height (in cm)"] == 0, "Height (in cm)"] = pim_data["Height (in cm)"].mean()

# %%
print(pim_data.iloc[19]['Height (in cm)'])
# Out:
# 161.11962629757787

# %%
pim_data
# Out:
#     By selecting 'I agree', you confirm that no coercion was exerted to fill this survey and you consent to provide information voluntarily without any monetary benefits attached to it. Do you agree?  \
# 0                                              I agree
# 1                                              I agree
# 2                                              I agree
# 3                                              I agree
# 4                                              I agree
# ..                                                 ...
# 284                                            I agree
# 285                                            I agree
# 286                                            I agree
# 287                                            I agree
# 288                                            I agree
#
#      Gender  Age  Height (in cm)  Weight (in kg)        BMI  Age at Menarche  \
# 0    Female   20          155.00           51.00  21.227888               15
# ...

# %%
# Cleaning values in column - Age at Menarche

# %%
pim_data.loc[pim_data["Age at Menarche"] > 1970, "Age at Menarche"] = 0

# %%
pim_data.loc[pim_data["Age at Menarche"] == 0, "Age at Menarche"] = pim_data["Age at Menarche"].mean()

# %%
print(pim_data.iloc[42]['Age at Menarche'])
# Out:
# 12.750865051903114

# %%
pim_data["Age at Menarche"] = pim_data["Age at Menarche"].astype('int64')

# %%
print(pim_data.iloc[42]['Age at Menarche'])
# Out:
# 12

# %%
# Cleaning values in column - What is the length of your menstrual cycle?

# %%
pim_data.loc[pim_data["What is the length of your menstrual cycle?"] < 10, "What is the length of your menstrual cycle?"] = 0

# %%
pim_data.loc[pim_data["What is the length of your menstrual cycle?"] == 0, "What is the length of your menstrual cycle?"] = pim_data["What is the length of your menstrual cycle?"].mean()

# %%
print(pim_data.iloc[99]['What is the length of your menstrual cycle?'])
# Out:
# 29.05536332179931

# %%
pim_data["What is the length of your menstrual cycle?"] = pim_data["What is the length of your menstrual cycle?"].astype('int64')

# %%
print(pim_data.iloc[99]['What is the length of your menstrual cycle?'])
# Out:
# 29

# %%
# Cleaning values in column - For how many days do you bleed?

# %%
pim_data.loc[pim_data["For how many days do you bleed?"] > 15, "For how many days do you bleed?"] = 0

# %%
pim_data.loc[pim_data["For how many days do you bleed?"] == 0, "For how many days do you bleed?"] = pim_data["For how many days do you bleed?"].mean()

# %%
print(pim_data.iloc[201]['For how many days do you bleed?'])
# Out:
# 4.844290657439446

# %%
pim_data["For how many days do you bleed?"] = pim_data["For how many days do you bleed?"].astype('int64')

# %%
print(pim_data.iloc[201]['For how many days do you bleed?'])
# Out:
# 4

# %%
pim_data
# Out:
#     By selecting 'I agree', you confirm that no coercion was exerted to fill this survey and you consent to provide information voluntarily without any monetary benefits attached to it. Do you agree?  \
# 0                                              I agree
# 1                                              I agree
# 2                                              I agree
# 3                                              I agree
# 4                                              I agree
# ..                                                 ...
# 284                                            I agree
# 285                                            I agree
# 286                                            I agree
# 287                                            I agree
# 288                                            I agree
#
#      Gender  Age  Height (in cm)  Weight (in kg)        BMI  Age at Menarche  \
# 0    Female   20          155.00           51.00  21.227888               15
# ...

# %%
pim_data.drop("By selecting 'I agree', you confirm that no coercion was exerted to fill this survey and you consent to provide information voluntarily without any monetary benefits attached to it. Do you agree?", axis='columns', inplace=True)

# %%
pim_data
# Out:
#      Gender  Age  Height (in cm)  Weight (in kg)        BMI  Age at Menarche  \
# 0    Female   20          155.00           51.00  21.227888               15
# 1    Female   20          154.00           54.00  22.769438               14
# 2    Female   18          160.00           54.00  21.093750               11
# 3    Female   19          160.00           46.70  18.242188               13
# 4    Female   18          162.50           57.00  21.585799               13
# ..      ...  ...             ...             ...        ...              ...
# 284  Female   16          158.00           45.00  18.025957               12
# 285  Female   19          156.00           60.00  24.654832               14
# 286  Female   20          168.91           58.85  20.626985               11
# 287  Female   21          157.00           52.00  21.096191               13
# 288  Female   24          155.00           70.00  29.136316               16
#
# ...

# %%
# Calculation of BMI

# %%
pim_data["BMI"] = (pim_data["Weight (in kg)"]/pim_data["Height (in cm)"]/pim_data["Height (in cm)"])*10000

# %%
temp = pim_data['BMI']
pim_data.drop(labels=['BMI'], axis=1, inplace = True)
pim_data.insert(4, 'BMI', temp)
pim_data
# Out:
#      Gender  Age  Height (in cm)  Weight (in kg)        BMI  Age at Menarche  \
# 0    Female   20          155.00           51.00  21.227888               15
# 1    Female   20          154.00           54.00  22.769438               14
# 2    Female   18          160.00           54.00  21.093750               11
# 3    Female   19          160.00           46.70  18.242188               13
# 4    Female   18          162.50           57.00  21.585799               13
# ..      ...  ...             ...             ...        ...              ...
# 284  Female   16          158.00           45.00  18.025957               12
# 285  Female   19          156.00           60.00  24.654832               14
# 286  Female   20          168.91           58.85  20.626985               11
# 287  Female   21          157.00           52.00  21.096191               13
# 288  Female   24          155.00           70.00  29.136316               16
#
# ...

# %%
# Calculation of Stress

# %%
pim_data["In the last month, how often have you felt confident about your ability to handle your personal problems?"].replace({0: 4, 1: 3, 3: 1, 4: 0}, inplace=True)

# %%
pim_data['In the last month, how often have you felt confident about your ability to handle your personal problems?']
# Out:
# 0      1
# 1      3
# 2      3
# 3      3
# 4      0
#       ..
# 284    1
# 285    3
# 286    0
# 287    0
# 288    2
# Name: In the last month, how often have you felt confident about your ability to handle your personal problems?, Length: 289, dtype: int64

# %%
pim_data["In the last month, how often have you felt that things were going your way?"].replace({0: 4, 1: 3, 3: 1, 4: 0}, inplace=True)

# %%
pim_data['In the last month, how often have you felt that things were going your way?']
# Out:
# 0      2
# 1      3
# 2      3
# 3      3
# 4      1
#       ..
# 284    1
# 285    0
# 286    3
# 287    2
# 288    2
# Name: In the last month, how often have you felt that things were going your way?, Length: 289, dtype: int64

# %%
pim_data["In the last month, how often have you been able to control irritations in your life?"].replace({0: 4, 1: 3, 3: 1, 4: 0}, inplace=True)

# %%
pim_data['In the last month, how often have you been able to control irritations in your life?']
# Out:
# 0      3
# 1      1
# 2      3
# 3      3
# 4      1
#       ..
# 284    2
# 285    0
# 286    1
# 287    2
# 288    1
# Name: In the last month, how often have you been able to control irritations in your life?, Length: 289, dtype: int64

# %%
pim_data["In the last month, how often have you felt that you were on top of things?"].replace({0: 4, 1: 3, 3: 1, 4: 0}, inplace=True)

# %%
pim_data['In the last month, how often have you felt that you were on top of things?']
# Out:
# 0      2
# 1      2
# 2      3
# 3      2
# 4      1
#       ..
# 284    2
# 285    3
# 286    4
# 287    2
# 288    1
# Name: In the last month, how often have you felt that you were on top of things?, Length: 289, dtype: int64

# %%
pd.set_option('display.max_columns', None)
pim_data.head()
# Out:
#    Gender  Age  Height (in cm)  Weight (in kg)        BMI  Age at Menarche  \
# 0  Female   20           155.0            51.0  21.227888               15
# 1  Female   20           154.0            54.0  22.769438               14
# 2  Female   18           160.0            54.0  21.093750               11
# 3  Female   19           160.0            46.7  18.242188               13
# 4  Female   18           162.5            57.0  21.585799               13
#
#    What is the length of your menstrual cycle?  \
# 0                                           25
# 1                                           30
# 2                                           28
# 3                                           33
# 4                                           25
#
#    For how many days do you bleed? Is your menstrual flow normal?  \
# 0                                4                            Yes
# 1                                4                            Yes
# ...

# %%
pim_data['Stress level']= pim_data.iloc[:, 23:33].sum(axis=1)

# %%
pim_data
# Out:
#      Gender  Age  Height (in cm)  Weight (in kg)        BMI  Age at Menarche  \
# 0    Female   20          155.00           51.00  21.227888               15
# 1    Female   20          154.00           54.00  22.769438               14
# 2    Female   18          160.00           54.00  21.093750               11
# 3    Female   19          160.00           46.70  18.242188               13
# 4    Female   18          162.50           57.00  21.585799               13
# ..      ...  ...             ...             ...        ...              ...
# 284  Female   16          158.00           45.00  18.025957               12
# 285  Female   19          156.00           60.00  24.654832               14
# 286  Female   20          168.91           58.85  20.626985               11
# 287  Female   21          157.00           52.00  21.096191               13
# 288  Female   24          155.00           70.00  29.136316               16
#
# ...

# %%
pim_data.drop(pim_data.iloc[:, 23:33], inplace = True, axis = 1)

# %%
pim_data
# Out:
#      Gender  Age  Height (in cm)  Weight (in kg)        BMI  Age at Menarche  \
# 0    Female   20          155.00           51.00  21.227888               15
# 1    Female   20          154.00           54.00  22.769438               14
# 2    Female   18          160.00           54.00  21.093750               11
# 3    Female   19          160.00           46.70  18.242188               13
# 4    Female   18          162.50           57.00  21.585799               13
# ..      ...  ...             ...             ...        ...              ...
# 284  Female   16          158.00           45.00  18.025957               12
# 285  Female   19          156.00           60.00  24.654832               14
# 286  Female   20          168.91           58.85  20.626985               11
# 287  Female   21          157.00           52.00  21.096191               13
# 288  Female   24          155.00           70.00  29.136316               16
#
# ...

# %%
temp1 = pim_data['Stress level']
pim_data.drop(labels=['Stress level'], axis=1, inplace = True)
pim_data.insert(23, 'Stress level', temp1)
pim_data
# Out:
#      Gender  Age  Height (in cm)  Weight (in kg)        BMI  Age at Menarche  \
# 0    Female   20          155.00           51.00  21.227888               15
# 1    Female   20          154.00           54.00  22.769438               14
# 2    Female   18          160.00           54.00  21.093750               11
# 3    Female   19          160.00           46.70  18.242188               13
# 4    Female   18          162.50           57.00  21.585799               13
# ..      ...  ...             ...             ...        ...              ...
# 284  Female   16          158.00           45.00  18.025957               12
# 285  Female   19          156.00           60.00  24.654832               14
# 286  Female   20          168.91           58.85  20.626985               11
# 287  Female   21          157.00           52.00  21.096191               13
# 288  Female   24          155.00           70.00  29.136316               16
#
# ...

# %%
pim_data.to_csv('PIM.csv')
