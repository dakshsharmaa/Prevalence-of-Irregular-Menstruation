# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data=pd.read_csv("https://raw.githubusercontent.com/dakshsharmaa/Prevalence-of-Irregular-Menstruation/Data/PIM_1.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  Age   BMI  Height (in cm)  Weight (in kg)  Age at Menarche  \
# 0           0   20  21.2           155.0            51.0             15.0
# 1           1   20  22.8           154.0            54.0             14.0
# 2           2   18  21.1           160.0            54.0             11.0
# 3           3   19  18.2           160.0            46.7             13.0
# 4           4   18  21.6           162.5            57.0             13.0
#
#    Length of menstrual cycle  For how many days do you bleed?  \
# 0                         25                                4
# 1                         30                                4
# 2                         28                                5
# 3                         33                                3
# 4                         25                                5
#
#   Is your menstrual flow normal? Have you ever faced irregular menstruation?  \
# ...

# %%
data = data.iloc[: , 1:]

# %%
pd.set_option("display.max_columns",None)
data.head()
# Out:
#    Age   BMI  Height (in cm)  Weight (in kg)  Age at Menarche  \
# 0   20  21.2           155.0            51.0             15.0
# 1   20  22.8           154.0            54.0             14.0
# 2   18  21.1           160.0            54.0             11.0
# 3   19  18.2           160.0            46.7             13.0
# 4   18  21.6           162.5            57.0             13.0
#
#    Length of menstrual cycle  For how many days do you bleed?  \
# 0                         25                                4
# 1                         30                                4
# 2                         28                                5
# 3                         33                                3
# 4                         25                                5
#
#   Is your menstrual flow normal? Have you ever faced irregular menstruation?  \
# 0                            Yes                                         Yes
# ...

# %%
data.iloc[: , 0:10].describe()
# Out:
#               Age         BMI  Height (in cm)  Weight (in kg)  \
# count  289.000000  289.000000      289.000000      289.000000
# mean    19.737024   22.123183      162.037972       54.233737
# std      2.849229    4.102089       15.723681       16.452008
# min     15.000000    3.200000      146.000000       10.000000
# 25%     18.000000   19.600000      155.000000       48.000000
# 50%     19.000000   22.000000      160.020000       55.000000
# 75%     20.000000   24.200000      165.500000       64.900000
# max     42.000000   39.000000      401.000000      110.000000
#
#        Age at Menarche  Length of menstrual cycle  \
# count       289.000000                 289.000000
# mean         12.795848                  29.564014
# std           1.362895                   6.858456
# min           8.000000                   0.000000
# 25%          12.000000                  28.000000
# 50%          13.000000                  30.000000
# 75%          14.000000                  30.000000
# ...

# %%
data.iloc[: , 10:27].describe()
# Out:
#        I eat a balanced diet/ I eat foods that are high in antioxidants, nutrient-dense, and with plenty of protein.  \
# count                                         289.000000
# mean                                            2.501730
# std                                             0.846252
# min                                             0.000000
# 25%                                             2.000000
# 50%                                             3.000000
# 75%                                             3.000000
# max                                             4.000000
#
#        I eat enough green vegetables.  \
# count                      289.000000
# mean                         2.608997
# std                          1.038857
# min                          0.000000
# 25%                          2.000000
# 50%                          3.000000
# 75%                          3.000000
# max                          4.000000
#
# ...

# %%
cor = data.corr()

# %%
cor.iloc[: , 0:10]
# Out:
#                                                          Age       BMI  \
# Age                                                 1.000000  0.271907
# BMI                                                 0.271907  1.000000
# Height (in cm)                                     -0.049602 -0.275465
# Weight (in kg)                                      0.113070  0.574032
# Age at Menarche                                     0.088956 -0.070139
# Length of menstrual cycle                          -0.006065  0.017947
# For how many days do you bleed?                    -0.121425 -0.120230
# For how long have you faced irregular menstruat...  0.171998  0.081478
# I eat a balanced diet/ I eat foods that are hig...  0.095233  0.000839
# I eat enough green vegetables.                      0.151659  0.019897
# I eat an ample amount of fruits rich in vitamin C.  0.077017  0.045408
# I regularly eat nuts.                               0.033417 -0.041804
# ...

# %%
cor.iloc[: , 10:27]
# Out:
#                                                     I eat an ample amount of fruits rich in vitamin C.  \
# Age                                                                                          0.077017
# BMI                                                                                          0.045408
# Height (in cm)                                                                               0.110765
# Weight (in kg)                                                                               0.123603
# Age at Menarche                                                                             -0.010691
# Length of menstrual cycle                                                                    0.056246
# For how many days do you bleed?                                                             -0.116269
# For how long have you faced irregular menstruat...                                           0.058399
# ...

# %%
plt.subplots(figsize=(10,10))
sns.heatmap(cor,cmap="Pastel1", square=True);
